# %%
#salary
salary = float(input("How much salary?"))
extra = float(input("How much extra?"))
print(salary+extra)
# Out:
# How much salary?1000
# How much extra?233
# 1233.0

# %%
#get salary with input
salary = float(input("How much salary?"))
extra = float(input("How much extra?"))

#create round
total_salary = round(salary+extra)

print(total_salary)
# Out:
# How much salary?150
# How much extra?23
# 173

# %%
#get salary with input
salary = float(input("How much salary?"))
extra = float(input("How much extra?"))

#create round
total_salary = round(salary+extra)

print(f"{total_salary:,}")
# Out:
# How much salary?1500
# How much extra?200
# 1,700

# %%
#get salary with input
salary = float(input("How much salary?"))
extra = float(input("How much extra?"))

#create round
daily_salary = (salary+extra)/30
daily_salary = round(daily_salary,2)

print(f"{daily_salary:,}")
# Out:
# How much salary?1500
# How much extra?500
# 66.67

# %%
#get salary with input
salary = float(input("How much salary?"))
extra = float(input("How much extra?"))

#create round
daily_salary = (salary+extra)/30


print(f"{daily_salary:.2f}")
print(f"{daily_salary:,}")
# Out:
# How much salary?15800
# How much extra?15
# 527.17
# 527.1666666666666

# %%
#booleans

a = True
b = False

if a == True:
  print("a é verdadeiro")
else:
  print("a é falso")
# Out:
# a é verdadeiro

# %%
# ask user for first name, remove blank space and capitalize the 1st letter
name= input("Whats your name?").strip().title()

#print output
print(f"Hello, {name}")

# %%
# define hello function
def hello():
  print("Hello")
# ask user for first name, remove blank space and capitalize the 1st letter
name= input("Whats your name?").strip().title()

hello()
# print output
print(f"Hello, {name}")
# Out:
# Whats your name?João
# Hello
# Hello, João

# %%
# define hello function with parameters
def hello(to):
  print("Hello", to)

# ask user for first name, remove blank space and capitalize the 1st letter
name= input("Whats your name?").strip().title()

hello(name)

# print output
#print(f"Hello, {name}")
# Out:
# Whats your name?joao
# Hello Joao

# %%
# define hello function with default parameters
def hello(to="World"):
  print("Hello", to)

# ask user for first name, remove blank space and capitalize the 1st letter
name= input("Whats your name?").strip().title()

hello(name)

# print output
print(hello())
# Out:
# Whats your name?joao
# Hello Joao
# Hello World
# None

# %%
def main():
  # ask user for first name, remove blank space and capitalize the 1st letter
  name= input("Whats your name?").strip().title()
  hello(name)

  # print output without expected arguments
  print(hello())

# define hello function with default parameters
def hello(to="World"):
  print("Hello, ", to)

main()
# Out:
# Whats your name?joao
# Hello Joao
# Hello World
# None

# %%
def main():
  x = int(input("Whats x?"))
  print("x squared is", square(x))

def square(n):
  return n*n

main()

a=square(50)
print(a)
# Out:
# Whats x?20
# x squared is 400
# 2500
