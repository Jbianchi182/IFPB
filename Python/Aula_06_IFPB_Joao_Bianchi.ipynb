# %%
try:
  x = int(input("What's x?"))
  print(f"X is {x}")
except ValueError:
  print("x is not an integer")
# Out:
# What's x?4.5
# x is not an integer

# %%
# O código abaixo apresenta erros propositais

try:
  x = int(input("What's x?"))
except ValueError:
  print("x is not an integer")

print(f"X is {x}")
# Out:
# What's x?a
# x is not an integer
# X is 10

# %%
try:
  x = int(input("What's x?"))
except ValueError:
  print("x is not an integer")
else:
  print(f"X is {x}")
# Out:
# What's x?10
# X is 10

# %%
while True:
  try:
    x = int(input("What's x?"))
  except ValueError:
    print("x is not an integer")
  else:
    break

print(f"X is {x}")
# Out:
# What's x?5
# X is 5

# %%
def main():
  x = get_int()
  print(f"X is {x}")

def get_int():
  while True:
    try:
      x = int(input("What's x?"))
    except ValueError:
      print("x is not an integer")
    else:
      return x

main()
# Out:
# What's x?a
# x is not an integer
# What's x?1
# X is 1

# %%
def main():
  x = get_int()
  print(f"X is {x}")

def get_int():
  while True:
    try:
      x = int(input("What's x? "))
    except ValueError:
      print("x is not an integer")
    else:
      break
  return x

main()

# %%
def main():
  x = get_int()
  print(f"X is {x}")

def get_int():
  while True:
    try:
      x = int(input("What's x? "))
      return x
    except ValueError:
      print("x is not an integer")

main()

# %%
def main():
  x = get_int()
  print(f"X is {x}")

def get_int():
  while True:
    try:
      return int(input("What's x? "))
    except ValueError:
      print("x is not an integer")

main()

# %%
def main():
  x = get_int()
  print(f"X is {x}")

def get_int():
  while True:
    try:
      return int(input("What's x? "))
    except ValueError:
      pass

main()

# %%
def main():
  x = get_int("What's x? ")
  print(f"X is {x}")
  y = get_int("What's y? ")
  print(f"Y is {y}")

def get_int(prompt):
  while True:
    try:
      return int(input(prompt))
    except ValueError:
      pass

main()
# Out:
# What's x? 10
# X is 10
# What's y? 20
# Y is 20
